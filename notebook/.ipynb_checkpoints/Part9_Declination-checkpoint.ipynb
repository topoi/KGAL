# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import *
from scipy.optimize import curve_fit
from scipy import stats
import scipy.cluster.hierarchy as sch
from scipy.stats import norm
from nested_lookup import nested_lookup
import json 
from citableclass import Citable
import warnings

# %%
def Plot(bins=5, mean=False):
    plt.close()
    plt.figure(figsize=(17,10))
    plt.subplot(211)
    plt.title("uncorrected probability for declination", fontsize=15)
    plt.xlabel("declination [°]", fontsize=15)
    plt.ylabel("prob", fontsize=15)
    #plt.plot(df["bins (dec)"][element], df['prob (dec)'][element])
    number = [item for sublist in list(df['bins (dec)']) for item in sublist]
    weightval = [item for sublist in list(df['prob (dec)']) for item in sublist]
    counts, bins, bars = plt.hist(number, color="green", bins=bins, stacked=True);
    weight, bins, bars = plt.hist(number, color="green", weights=weightval, bins=bins, stacked=True);
    final = np.array(weight/counts)
    plt.close()
    plt.figure(figsize=(17,10))
    plt.hist(final, bins=bins, color="blue") 
    return plt.show()

# %%
#plt.hist(df['prob (dec)'], weights=df['prob (dec)'], bins=5);

# %% [markdown]
# #### Explanation data file:  values_n500_th7_sig0.2_start0.5.json
# n500 = 500 iteration steps
# th7 = threshold 7% std err allowed for linear regression
# sig0.2 = allowed deviation of observer from start position
# start = position of observer (0.5 means center of neolethic enclosure)

# %%
cite1 = Citable("values_n500_th7_sig0.2_start0.5.json", formats="local")
cite2 = Citable("values_n500_th20_sig0.2_start0.5.json", formats="local")
cite3 = Citable("values_n500_th7_sig0.2_start0.4.json", formats="local")
cite4 = Citable("values_n500_th7_sig0.2_start0.6.json", formats="local")
# Out:
# Please set project='NAME' parameter, trying to guess data path and project name...
# Please set project='NAME' parameter, trying to guess data path and project name...
# Please set project='NAME' parameter, trying to guess data path and project name...
# Please set project='NAME' parameter, trying to guess data path and project name...

# %%
df = cite1.digitalresource()
df.head()
# Out:
#    gate        object   latitude  longitude  \
# 0     1  QuedlinburgI  51.813308  11.178354
# 1     2  QuedlinburgI  51.813308  11.178354
# 2     3  QuedlinburgI  51.813308  11.178354
# 3     5  QuedlinburgI  51.813308  11.178354
# 4     6  QuedlinburgI  51.813308  11.178354
#
#                                              azimuth  \
# 0  [322.3842, 327.00188, 323.12422, 323.08902, 32...
# 1  [351.01251, 354.8507, 358.56612, 357.6451, 332...
# 2  [23.69989, 32.14198, 25.37369, 28.19498, 40.49...
# 3  [201.27716, 209.68904, 214.9198, 232.62122, 25...
# 4  [272.61056, 271.60254, 290.59903, 272.63833, 2...
#
#                                            prob (az)  \
# 0  [0.0051973571, 0.0088017131, 0.0141468533, 0.0...
# 1  [5.03205e-05, 0.0001232569, 0.0002836046, 0.00...
# 2  [0.0080065388, 0.012579221000000002, 0.0187604...
# 3  [0.005353713, 0.0081419226, 0.0115522043, 0.01...
# 4  [0.014995497100000001, 0.0201580286, 0.0253152...
#
#                                            bins (az)  mean azimuth  \
# 0  [311.07258, 312.0136455, 312.954711, 313.89577...    321.031097
# 1  [318.85383, 320.910204, 322.966578, 325.022952...    349.334866
# 2  [15.08685, 16.3571395, 17.627429, 18.8977185, ...     26.740795
# 3  [180.24332, 184.690066, 189.136812, 193.583558...    209.334273
# 4  [270.01734, 273.137112, 276.256884, 279.376656...    285.140638
#
#    sigma azimuth                                        declination  \
# 0       4.116950  [29.32152, 31.23161, 29.63959, 29.62456, 31.12...
# 1       8.222334  [37.63547, 38.00504, 38.17258, 38.14864, 33.39...
# 2       5.566104  [34.47779, 31.56542, 33.95813, 33.01579, 28.04...
# 3      16.881310  [-35.17566, -32.48434, -30.45868, -22.04369, -...
# 4      11.959366  [1.6135700000000002, 0.99065, 12.5627, 1.63073...
#
#                                           prob (dec)  \
# 0  [0.0081646945, 0.0142723486, 0.0236836793, 0.0...
# 1  [4.24e-08, 2.3380000000000002e-07, 1.1678e-06,...
# 2  [0.0032915805000000003, 0.0063176233, 0.011475...
# 3  [0.0351919019, 0.0455862836, 0.054382477000000...
# 4  [0.0242711434, 0.0323261855, 0.0406479134, 0.0...
#
#                                           bins (dec)  mean declination  \
# 0  [23.9653, 24.3836405, 24.801981, 25.2203215, 2...         28.663975
# 1  [27.74548, 28.2675405, 28.789601, 29.3116615, ...         36.986638
# 2  [28.04431, 28.4745655, 28.904821, 29.3350765, ...         33.352077
# 3  [-38.18629, -36.3023765, -34.418463, -32.53454...        -31.324412
# 4  [0.01072, 1.6714665, 3.332213, 4.9929594999999...          9.115712
#
#    sigma declination
# 0           1.833795
# 1           1.656965
# 2           1.833239
# 3           6.564686
# 4           6.924614

# %% [markdown]
# ### available keys

# %%
cite1.documentation()
# Out:
# <style  type="text/css" >
#     #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7 th {
#           text-align: left;
#     }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row0_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row0_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row1_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row1_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row2_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row2_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row3_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row3_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row4_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row4_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row5_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row5_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row6_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row6_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row7_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row7_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row8_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row8_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row9_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row9_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row10_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row10_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row11_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row11_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row12_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row12_col1 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row13_col0 {
#             text-align:  left;
#         }    #T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row13_col1 {
#             text-align:  left;
#         }</style>
# <table id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Value</th>
#         <th class="col_heading level0 col1" >Description</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row0_col0" class="data row0 col0" >gate</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row0_col1" class="data row0 col1" >number of gate </td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row1_col0" class="data row1 col0" >object</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row1_col1" class="data row1 col1" >name of place</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row2_col0" class="data row2 col0" >latitude</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row2_col1" class="data row2 col1" >geographic latitude</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row3_col0" class="data row3 col0" >longitude</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row3_col1" class="data row3 col1" >geographic longitude</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row4_col0" class="data row4 col0" >azimuth</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row4_col1" class="data row4 col1" >astronomical azimuth</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row5_col0" class="data row5 col0" >prob (az)</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row5_col1" class="data row5 col1" >probability azimuth value</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row6_col0" class="data row6 col0" >bins (az)</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row6_col1" class="data row6 col1" >azimuth value</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row7_col0" class="data row7 col0" >mean azimuth</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row7_col1" class="data row7 col1" >mean azimuth value from normal distribution</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row8_col0" class="data row8 col0" >sigma azimuth</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row8_col1" class="data row8 col1" >standard deviation</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row9_col0" class="data row9 col0" >declination</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row9_col1" class="data row9 col1" >astronomical declination</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row10" class="row_heading level0 row10" >10</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row10_col0" class="data row10 col0" >prob (dec)</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row10_col1" class="data row10 col1" >probability declination value</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row11" class="row_heading level0 row11" >11</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row11_col0" class="data row11 col0" >bins (dec)</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row11_col1" class="data row11 col1" >declination value</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row12" class="row_heading level0 row12" >12</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row12_col0" class="data row12 col0" >mean declination</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row12_col1" class="data row12 col1" >mean declination value from normal distribution</td>
#     </tr>    <tr>
#         <th id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7level0_row13" class="row_heading level0 row13" >13</th>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row13_col0" class="data row13 col0" >sigma declination</td>
#         <td id="T_8930ba64_e43a_11e8_95ec_c9f5f0e008d7row13_col1" class="data row13 col1" >standard deviation </td>
#     </t

# %%
pd.DataFrame(df[["gate","mean declination", "sigma declination"]]).head()
# Out:
#    gate  mean declination  sigma declination
# 0     1         28.663975           1.833795
# 1     2         36.986638           1.656965
# 2     3         33.352077           1.833239
# 3     5        -31.324412           6.564686
# 4     6          9.115712           6.924614
