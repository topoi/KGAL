# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set_style('whitegrid')
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import norm
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KernelDensity
from citableclass import Citable
from corpussearch import search
import ephem

# %% [markdown]
# # Load data

# %% [markdown]
# n200  = number of iterations steps
# th10  = allowed std err for linear regression
# sig0.2 = observer deviation from start point
# start0.5 = observer start point

# %%
cite1 = Citable("values_n200_th10_sig0.2_start0.5.json", formats="local", project="kreisgrabenanlage")
cite2 = Citable("values_n500_th15_sig0.2_start0.5.json", formats="local", project="kreisgrabenanlage")
cite3 = Citable("values_n1500_th10_sig0.3_start0.5.json", formats="local", project="kreisgrabenanlage")
cite4 = Citable("values_n2500_th5_sig0.4_start0.5.json", formats="local", project="kreisgrabenanlage")
#######!!!    nur cite 5 und cite 6 hat die Azimuthe von T. Michel    !!!########
####### aber reicht ja, sind j eh immer die selben ########
cite5 = Citable("values_n550_th15_sig0.2_start0.5.json", formats="local", project="kreisgrabenanlage")
cite6 = Citable("values_n550_th55_sig0.2_start0.5.json", formats="local", project="kreisgrabenanlage")
df = cite5.digitalresource()
df.head()
# Out:
#    gate        object   latitude  longitude  \
# 0     1  QuedlinburgI  51.813308  11.178354
# 1     2  QuedlinburgI  51.813308  11.178354
# 2     3  QuedlinburgI  51.813308  11.178354
# 3     5  QuedlinburgI  51.813308  11.178354
# 4     6  QuedlinburgI  51.813308  11.178354
#
#                                              azimuth  \
# 0  [318.5567, 318.466, 301.67631, 330.67859, 311....
# 1  [357.99142, 351.97775, 321.03162, 358.42307, 3...
# 2  [39.74462, 34.41164, 14.3832, 20.67756, 17.453...
# 3  [188.82668, 215.66022, 222.96723, 202.34319, 2...
# 4  [284.53739, 295.55975, 279.70906, 279.29026, 3...
#
#                                            prob (az)  \
# 0  [0.0015117788000000001, 0.0027730629, 0.004810...
# 1  [5.2436e-06, 1.67168e-05, 4.92572e-05, 0.00013...
# 2  [0.0048290551, 0.0078198874, 0.011896451300000...
# 3  [0.004886123, 0.007579714800000001, 0.01096853...
# 4  [0.0157409835, 0.022881678500000002, 0.0296101...
#
#                                            bins (az)  mean azimuth  \
# 0  [301.22092, 302.909169, 304.597418, 306.285667...    320.423137
# 1  [313.39173, 315.721499, 318.051268, 320.381037...    348.852293
# 2  [11.24346, 13.7487415, 16.254023, 18.7593045, ...     31.833283
# 3  [180.08317, 184.365925, 188.64868, 192.931435,...    209.273072
# 4  [270.00451, 273.875465, 277.74642, 281.617375,...    284.391778
#
#    sigma azimuth                                        declination  \
# 0       7.147553  [27.60859, 27.56668, 18.94393, 32.61713, 24.08...
# 1       8.301546  [38.15901, 37.747, 28.72893, 38.16963, 37.9682...
# 2      10.025190  [28.38247, 30.6662, 36.78745, 35.33817, 36.140...
# 3      16.242891  [-37.65491, -30.15238, -26.89667, -34.87665, -...
# 4      11.351395  [8.92735, 15.47006, 5.98458, 5.72788, 26.05564...
#
#                                           prob (dec)  \
# 0  [0.0015926656, 0.0031116714, 0.0057481814, 0.0...
# 1  [0.0, 2e-10, 2.3e-09, 2.11e-08, 1.695e-07, 1.1...
# 2  [0.0001141817, 0.00029401570000000003, 0.00070...
# 3  [0.0354914898, 0.0465834335, 0.0563111278, 0.0...
# 4  [0.0253207186, 0.0354082901, 0.0456947111, 0.0...
#
#                                           bins (dec)  mean declination  \
# 0  [18.69019, 19.4592955, 20.228401, 20.9975065, ...         28.268624
# 1  [25.13234, 25.7850575, 26.437775, 27.0904925, ...         36.909942
# 2  [17.24282, 18.2470195, 19.251219, 20.2554185, ...         31.221370
# 3  [-38.18664, -36.4089685, -34.631297, -32.85362...        -31.424014
# 4  [0.0027900000000000004, 1.8583129999999999, 3....          8.680300
#
#    sigma declination  number elements  \
# 0           3.249270                5
# 1           1.724592                1
# 2           3.782583                2
# 3           6.196391                1
# 4           6.548552                1
#
#                                   azimuth(michel)
# 0  [[134, 136], [21, 23], [214, 217], [312, 313]]
# 1  [[134, 136], [21, 23], [214, 217], [312, 313]]
# 2  [[134, 136], [21, 23], [214, 217], [312, 313]]
# 3  [[134, 136], [21, 23], [214, 217], [312, 313]]
# 4  [[134, 136], [21, 23], [214, 217], [312, 313]]

# %% [markdown]
# ### make subset from Michels data

# %%
az_michel=list()
for i in range(len(df["azimuth(michel)"])):
    for j in range(len(df["azimuth(michel)"][i])):
        az_michel.append(np.mean(df["azimuth(michel)"][i][j]))
data=np.array(list(set(az_michel)))

# %% [markdown]
# ### Anmerkung!!:
# - die unterschiedliche Anzahl macht Sinn, da bei Michel alle 90 Gates vorkommen, bei der linearen Regression nur 53
# - bei der linearen Regression hängt es davon ab wie groß die Threshold ist

# %%
plt.figure(figsize=(10,8))
plt.hist(data, bins=12, alpha=.6, density=False, label="Michel (mean value)")
plt.hist(np.array(df["mean azimuth"]), bins=12, alpha=.6, density=False, label="from linear regression")
plt.title('Azimuth values from Michel', fontsize=14);
plt.xlabel("Azimuth [°]", fontsize=14);
plt.ylabel("#", fontsize=14);
plt.legend()

# %% [markdown]
# ## Auxiliary functions

# %%
# auxiliary to simplify normal distributions for n data points
def ndi(mu,sd,n):
    b=np.random.normal(mu,sd,n)
    return(b)

# %% [markdown]
# # Simulation
# ## Generation of mixed distribution

# %% [markdown]
# ## Parameter

# %%
# no of gates, gaussian distribution of directions
n_gates= 4
# mean values
#value:  -30.361514640687762 var 9.488898890923112
#value:  37.18086067610277 var 14.458853132679794
#value:  12.767138961255649 var 4.543496345526992
#value:  -8.563945763567334 var 5.7156606842991975
#value:  -37.42626719012814 var 8.738291591935992

mu=(-37,-30,-8,12,37,45,26,19)
# std. variation
sd=1
# additional noise
noise_bmg = 0.5
# number of simulated directions
n=250

# %% [markdown]
# ### Mixed distribution of simulated data points

# %%
# mixed distribution from simulation
a = [ndi(mu[i],sd,n) for i in range(n_gates)]
bmg=np.concatenate(a)
# simulated data for mixed distribution
data = np.random.normal(bmg, noise_bmg)[:, np.newaxis]

# %%
sns.distplot(data);
# Out:
# /mnt/ResearchCloud/Projects/kreisgrabenanlage/.kernel/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
n_components = np.arange(1, 21)
models = [GaussianMixture(n, covariance_type='spherical').fit(data) for n in n_components]

# %%
plt.figure(figsize=(9,7))
plt.plot(n_components, [m.bic(data) for m in models], label='BIC')
plt.plot(n_components, [m.aic(data) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %% [markdown]
# # Site data

# %%
# minimal number of defining features pro gates
number=0
# upper bound for sigma
sigma=4
# minimum declination
mdec=-50
# max azimuth
maxaz=380
# list of empirical deviations sd from selected gates
sel_df=df[["mean declination","sigma declination"]][(df["mean azimuth"] < maxaz) & (df["mean declination"] > mdec) & (df["number elements"] > number) & (df["sigma declination"]< sigma)]
sel_df.head()
# Out:
#    mean declination  sigma declination
# 0         28.268624           3.249270
# 1         36.909942           1.724592
# 2         31.221370           3.782583
# 5         31.516133           3.569968
# 6        -30.497132           3.281430

# %%
l1=sel_df["mean declination"].tolist()
l2=sel_df["sigma declination"].tolist()
print(len(l1),len(l2))
# Out:
# 21 21

# %%
# mixed distribution from simulation
b = tuple([ndi(l1[i],l2[i],n) for i in range(len(l1))])
bmg=np.concatenate(b)
# simulated data for mixed distribution
data = np.random.normal(bmg, noise_bmg)[:, np.newaxis]

# %%
plt.hist(data, bins='auto', alpha=.6, density=True)
# Out:
# (array([0.00751029, 0.02740242, 0.01446964, 0.00698834, 0.01354173,
#         0.00809024, 0.00173984, 0.00014499, 0.00414661, 0.00298672,
#         0.00379864, 0.01560053, 0.03207099, 0.01374471]),
#  array([-45.8270126 , -39.25825074, -32.68948889, -26.12072703,
#         -19.55196517, -12.98320331,  -6.41444145,   0.15432041,
#           6.72308226,  13.29184412,  19.86060598,  26.42936784,
#          32.9981297 ,  39.56689156,  46.13565341]),
#  <a list of 14 Patch objects>)

# %%
sns.distplot(data);
# Out:
# /mnt/ResearchCloud/Projects/kreisgrabenanlage/.kernel/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
gmm = GaussianMixture(n_gates,covariance_type='spherical')
gmm.fit(data)
x = np.linspace(-45, 45, 3 * 2500 + 1)
plt.figure(figsize=(9,7))
plt.hist(data, bins='auto', alpha=.3, density=True, log=False)

for i in np.arange(n_gates):
    mu=gmm.means_[i,0]
    var=gmm.covariances_[i]
    print("value: ", mu,"var",var)
    plt.vlines(mu, ymin=0, ymax=0.05, label='Fitted Means')
    plt.plot(x, norm.pdf(x, mu, np.sqrt(var)))
    plt.legend()
    plt.title('Gaussian Mixture Model')
# Out:
# value:  35.73907935374162 var 21.4647307804695
# value:  -34.91026558060142 var 17.458338745616064
# value:  -15.290430108154498 var 30.830171778233538
# value:  15.51623047638842 var 31.011401570038718

# %% [markdown]
# ### Anzahl der Gaussians entnommen aus AIC/BIC

# %% [markdown]
# The optimal number of clusters is the value that minimizes the AIC or BIC, depending on which approximation we wish to use. The AIC tells us that our choice of 16 components above was probably too many: around 8-12 components would have been a better choice. As is typical with this sort of problem, the BIC recommends a simpler model.
#
# Notice the important point: this choice of number of components measures how well GMM works as a density estimator, not how well it works as a clustering algorithm. I'd encourage you to think of GMM primarily as a density estimator, and use it for clustering only when warranted within simple datasets.

# %%
n_components = np.arange(1, 21)
models = [GaussianMixture(n, covariance_type='spherical').fit(data) for n in n_components]

# %%
plt.figure(figsize=(9,7))
plt.plot(n_components, [m.bic(data) for m in models], label='BIC')
plt.plot(n_components, [m.aic(data) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
# best n gates according to BIC
n_gates=5
gmm = GaussianMixture(n_gates,covariance_type='spherical')
gmm.fit(data)
x = np.linspace(-45, 45, 3 * 2500 + 1)
plt.figure(figsize=(9,7))
plt.hist(data, bins='auto', alpha=.3, density=True, log=False)

for i in np.arange(n_gates):
    mu=gmm.means_[i,0]
    var=gmm.covariances_[i]
    print("value: ", mu,"var",var)
    plt.vlines(mu, ymin=0, ymax=0.05, label='Fitted Means')
    plt.plot(x, norm.pdf(x, mu, np.sqrt(var)))
    plt.legend()
    plt.title('Gaussian Mixture Model')
# Out:
# value:  35.358926778271375 var 25.12988225669176
# value:  -31.240604062151593 var 9.636554253376973
# value:  -15.328586544007141 var 31.43577930111204
# value:  12.897564272529227 var 6.8828589830064315
# value:  -37.16846898575403 var 8.56901065900354

# %% [markdown]
# # 1d GMM Modeling Literature
#
# https://km3pipe.readthedocs.io/en/latest/auto_examples/stats/plot_fitting_dists.html
#
# B.W. Silverman, “Density Estimation for Statistics and Data Analysis”
# Hastie, Tibshirani and Friedman, “The Elements of Statistical Learning: Data Mining, Inference, and Prediction”, Springer (2009)
# Liu, R., Yang, L. “Kernel estimation of multivariate cumulative distribution function.” Journal of Nonparametric Statistics (2008)

# %%
dens = sm.nonparametric.KDEUnivariate(data)
dens.fit()

kde_sm = dens.evaluate(x)
plt.fill_between(x, kde_sm, alpha=.5, label='KDE')
plt.hist(data, bins='auto', alpha=.3, density=True)
# Out:
# /mnt/ResearchCloud/Projects/kreisgrabenanlage/.kernel/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (array([0.00751029, 0.02740242, 0.01446964, 0.00698834, 0.01354173,
#         0.00809024, 0.00173984, 0.00014499, 0.00414661, 0.00298672,
#         0.00379864, 0.01560053, 0.03207099, 0.01374471]),
#  array([-45.8270126 , -39.25825074, -32.68948889, -26.12072703,
#         -19.55196517, -12.98320331,  -6.41444145,   0.15432041,
#           6.72308226,  13.29184412,  19.86060598,  26.42936784,
#          32.9981297 ,  39.56689156,  46.13565341]),
#  <a list of 14 Patch objects>)

# %% [markdown]
# # Astronomy

# %%
cite1 = Citable("brightstars_declination.json", formats="local", project="computationalastronomy")
cite2 = Citable("brightstars1,6_declination.json", formats="local", project="computationalastronomy")

# %%
df_stars = cite2.digitalresource()
df_stars
# Out:
#         Achernar  Aldebaran     Rigel    Capella  Betelgeuse    Canopus  \
# -4000 -57.169896  16.825185 -8.200734  46.710741    7.388852 -52.735266
# -4200 -57.167670  16.835702 -8.200703  46.734464    7.388249 -52.736581
# -4400 -57.165444  16.846220 -8.200672  46.758187    7.387646 -52.737895
# -4600 -57.163217  16.856737 -8.200640  46.781910    7.387043 -52.739210
# -4800 -57.160991  16.867254 -8.200609  46.805633    7.386440 -52.740525
# -5000 -57.158765  16.877771 -8.200578  46.829357    7.385836 -52.741839
#
#           Sirius      Adara     Castor   Procyon    ...        Regulus  \
# -4000 -14.675475 -28.976037  32.135470  6.951050    ...      11.959042
# -4200 -14.607544 -28.976164  32.143700  7.008512    ...      11.958770
# -4400 -14.539613 -28.976292  32.151931  7.065974    ...      11.958497
# -4600 -14.471682 -28.976419  32.160161  7.123435    ...      11.958224
# -4800 -14.403751 -28.976546  32.168391  7.180897    ...      11.957952
# -5000 -14.335820 -28.976673  32.176621  7.238359    ...      11.957679
#
#           Mimosa      Spica      Agena   Arcturus    Antares       Vega  \
# -4000 -59.667254 -11.108251 -60.331307  22.518107 -26.393278  38.304164
# -4200 -59.666542 -11.106488 -60.329915  22.629156 -26.391989  38.288198
# -4400 -59.665830 -11.104726 -60.328523  22.740204 -26.390700  38.272232
# -4600 -59.665118 -11.102964 -60.327131  22.851253 -26.389411  38.256266
# -4800 -59.664406 -11.101202 -60.325740  22.962302 -26.388122  38.240301
# -5000 -59.663694 -11.099439 -60.324348  23.073350 -26.386832  38.224335
#
#          Altair      Deneb  Fomalhaut
# -4000  8.225213  45.277696 -29.348363
# -4200  8.203799  45.277609 -29.339242
# -4400  8.182386  45.277523 -29.330122
# -4600  8.160973  45.277437 -29.321001
# -4800  8.139560  45.277351 -29.311880
# -5000  8.118146  45.277265 -29.302759
#
# [6 rows x 21 columns]

# %% [markdown]
# ### Combine statistics with astronomy

# %%
def Combine(year=-4000):
    xcoords=list()
    labels=list()
    for element in df_stars.keys():
        xcoords.append(df_stars[element][year])
        labels.append(element)
    n_gates=5
    gmm = GaussianMixture(n_gates,covariance_type='spherical')
    gmm.fit(data)
    x = np.linspace(-45, 45, 3 * 2500 + 1)
    plt.figure(figsize=(32,10))
    plt.hist(data, bins='auto', alpha=.3, density=True, log=False)

    for i in np.arange(n_gates):
        mu=gmm.means_[i,0]
        var=gmm.covariances_[i]
        print("value: ", mu,"var",var)
        plt.vlines(mu, ymin=0, ymax=0.05, label='Fitted Means')
        plt.plot(x, norm.pdf(x, mu, np.sqrt(var)))
        plt.legend()
        plt.title('Gaussian Mixture Model')
    for xc,c in zip(xcoords,labels):
        plt.axvline(x=xc, label='line at x = {}'.format(n), c='r')
    plt.xticks(xcoords, labels, rotation='vertical')
    return plt.show()

# %%
Combine(year=-5000)
# Out:
# value:  -34.94532693709151 var 17.206427856580948
# value:  29.745121658383585 var 12.822375784733369
# value:  38.215531978185346 var 7.304818767006171
# value:  -15.35750579727892 var 31.688388514202533
# value:  12.852317158230017 var 6.53466090030341

# %% [markdown]
# # Show all Sites

# %%
sites = Citable("sites.json", formats="local", project="kreisgrabenanlage")
df=sites.digitalresource()
df.head()
# Out:
#            object                                        coordinates  \
# 0   Quedlinburg I  {'latitude': 51.8138447, 'longitude': 11.1772177}
# 1  Quedlinburg II     {'latitude': 51.81162, 'longitude': 11.108083}
# 2          Bielen    {'latitude': 51.482888, 'longitude': 10.865373}
# 3          Bochow    {'latitude': 51.962024, 'longitude': 13.083037}
# 4          Goseck     {'latitude': 51.198242, 'longitude': 11.86464}
#
#   altitude_asl  diameter                                     inner_diameter  \
# 0          124            Distance from northwest gate to southeast gate...
# 1          126  no entry                                           no entry
# 2          172      48 m                                           no entry
# 3           80   60-80 m                                           no entry
# 4          160   71-75 m                                           no entry
#
#                                       outer_diameter  \
# 0  About 98 meters at the largest width of the ou...
# 1  around 60-62 meters at the largest width of th...
# 2                                           no entry
# 3                                           no entry
# 4                                           no entry
#
#                                       number_ditches  \
# 0  Two trenches and an irregular third ditch with...
# 1  Two circular ditches and a third, irregular, p...
# 2                        one simple, circular trench
# 3  double circular enclosure with v-shaped ditche...
# 4  one simple, nearly circular ditch with a v-sha...
#
#                                     number_palisades  entrance_numbers  \
# 0  Not obvious from geomagnetics; two rows of pal...               4.0
# 1                Three concentric rings of palisades               NaN
# 2  three concentric palisade rings with occasiona...               NaN
# 3  three concentric palisade ditches, one poorly ...               NaN
# 4  two concentric palisade trenches with a distan...               NaN
#
#           entrance_type      ...       \
# 0  Lochenice-Unternberg      ...
# 1                  None      ...
# 2                  None      ...
# 3                  None      ...
# 4                  None      ...
#
#                                            resources outlet_numbers  \
# 0  {'overview': 'KGAL0001', 'plots': 'KGAL0002', ...           None
# 1  {'overview': 'KGAL0005', 'plots': 'KGAL0006', ...  3, possibly 4
# 2  {'overview': 'KGAL0009', 'plots': 'KGAL0010', ...              3
# 3  {'overview': 'KGAL0013', 'plots': 'KGAL0014', ...              5
# 4  {'overview': 'KGAL0017', 'plots': 'KGAL0018', ...           None
#
#                                          outlet_type  \
# 0                                               None
# 1                       Kothingeichendorf-TÄÅ¡etice
# 2                                     BuÄany-Svodin
# 3  mixed: Literski in NW, others Kothingeichendor...
# 4                                     BuÄany-Svodin
#
#                                   outlet_orientation  \
# 0                                               None
# 1  Ditch outlets to the northwest, northeast and ...
# 2           outlets to the southeast, south and west
# 3  at least one outlet in the northwest, ditch in...
# 4      outlets to the north, southeast and southwest
#
#                                          outlet_info outlet _numbers  \
# 0                                               None             NaN
# 1  Northe postulated another outlet to the southe...             NaN
# 2  each outlet with smaller, centrally-placed tre...             NaN
# 3                                           no entry             NaN
# 4  other interruptions in the palisade trenches (...             3.0
#
#   outlet _type outlet _orientation StÃ€uble altitude_masl
# 0         None                None     None           NaN
# 1         None                None     None           NaN
# 2         None                None     None           NaN
# 3         None                None     None           NaN
# 4         None                None     None           NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ### creat sub-dataframe

# %%
sites = df[["object","resources"]]
sites.head()
# Out:
#            object                                          resources
# 0   Quedlinburg I  {'overview': 'KGAL0001', 'plots': 'KGAL0002', ...
# 1  Quedlinburg II  {'overview': 'KGAL0005', 'plots': 'KGAL0006', ...
# 2          Bielen  {'overview': 'KGAL0009', 'plots': 'KGAL0010', ...
# 3          Bochow  {'overview': 'KGAL0013', 'plots': 'KGAL0014', ...
# 4          Goseck  {'overview': 'KGAL0017', 'plots': 'KGAL0018', ...

# %%
def ShowSites(site="", types="plots"):
    obj= sites["resources"][(sites["object"] == site)][0]
    d=Citable(obj[types], formats="et")
    return d.imageshow(())

# %%
ShowSites(site="Quedlinburg I", types="plots")
# Out:
# <img src="https://repository.edition-topoi.org/CitableHandler/KGAL/single/0002/0?getDigitalFormat" height="500"/>
